# %% [markdown]
# # Egzersiz 1
#
# ## Hedefler:
# - Öğrencinin sıfırdan sınıf oluşturma becerilerini geliştirmek
# - Örnek değişkenleri tanımlamayı ve kullanmayı öğrenmek
# - Metotları tanımlamayı ve kullanmayı öğrenmek
#
# ## Senaryo:
# Saniyeleri sayabilen bir sınıfa ihtiyacımız var. Basit görünebilir, ancak belirli gereksinimlerimiz var.
#
# Gereksinimleri dikkatlice okuyun çünkü oluşturacağınız sınıf, Mars'a uluslararası görevler taşıyan roketlerin fırlatılması için kullanılacak. Bu büyük bir sorumluluk ve size güveniyoruz!
#
# Sınıfınızın adı Timer olacak. Kurucu metot, saat (0..23 aralığında bir değer - askeri zaman), dakika (0..59 aralığında) ve saniye (0..59 aralığında) temsil eden üç argüman kabul etmeli.
#
# Tüm parametreler için varsayılan değer sıfırdır. Doğrulama kontrolleri yapmaya gerek yoktur.
#
# Sınıf aşağıdaki özellikleri sağlamalıdır:
# - Sınıfın nesneleri "yazdırılabilir" olmalı, yani kendilerini "hh:mm:ss" formatında, herhangi bir değer 10'dan küçük olduğunda başına sıfır ekleyerek dizelere dönüştürebilmelidir.
# - Sınıf, nesnelerin içinde depolanan zamanı sırasıyla +1/-1 saniye artıran veya azaltan next_second() ve previous_second() adlı parametresiz metotlarla donatılmalıdır.
#
# ## İpuçları:
# - Tüm nesne özellikleri özel olmalıdır.
# - Zaman dizisini biçimlendirmek için ayrı bir fonksiyon (metot değil) yazmayı düşünün.
#
# Editörde sağlanan şablonu tamamlayın. Kodunuzu çalıştırın ve çıktının bizimkiyle aynı görünüp görünmediğini kontrol edin.
#
# ## Beklenen Çıktı:
# 23:59:59
# 00:00:00
# 23:59:59

# %%
class Timer:
    def __init__( ??? ):
        #
        # Write code here
        #

    def __str__(self):
        #
        # Write code here
        #

    def next_second(self):
        #
        # Write code here
        #

    def prev_second(self):
        #
        # Write code here
        #


timer = Timer(23, 59, 59)
print(timer)
timer.next_second()
print(timer)
timer.prev_second()
print(timer)

# %% [markdown]
# # Egzersiz 2
#
# ## Hedefler:
# - Öğrencinin sıfırdan sınıf oluşturma becerilerini geliştirmek
# - Örnek değişkenleri tanımlamayı ve kullanmayı öğrenmek
# - Metotları tanımlamayı ve kullanmayı öğrenmek
#
# ## Senaryo:
# Göreviniz, Weeker adlı bir sınıfı uygulamaktır. Evet, doğru okudunuz – bu isim, o sınıfın nesnelerinin haftanın günlerini saklayıp manipüle edebileceğini gösteriyor.
#
# Sınıfın kurucu metodu bir argüman kabul eder – bu argüman haftanın gününün adını temsil eden bir string olmalıdır. Kabul edilebilir tek değerler şunlardır:
#
# Mon, Tue, Wed, Thu, Fri, Sat, Sun
#
# Bu setin dışındaki bir argümanla kurucuyu çağırmak WeekDayError istisnasını yükseltmelidir (bu istisnayı kendiniz tanımlayın; endişelenmeyin, yakında istisnaların nesnel doğasını konuşacağız). Sınıf aşağıdaki özellikleri sağlamalıdır:
#
# - Sınıfın nesneleri "yazdırılabilir" olmalı, yani kendilerini kurucu argümanlarla aynı formda dizelere dönüştürebilmelidir.
# - Sınıf, add_days(n) ve subtract_days(n) adlı bir parametreli metotlarla donatılmalıdır. Burada, n, nesnenin içinde saklanan haftanın gününü belirtilen gün sayısına göre ileriye veya geriye güncelleyerek değiştiren bir tam sayı olmalıdır.
# - Tüm nesne özellikleri özel olmalıdır.
#
# Editörde sağlanan şablonu tamamlayın, kodunuzu çalıştırın ve çıktınızın bizimkiyle aynı görünüp görünmediğini kontrol edin.
#
# ## Beklenen Çıktı:
# Mon
# Tue
# Sun
# Üzgünüm, isteğinizi yerine getiremiyorum.

# %%
class WeekDayError(Exception):
    pass
	

class Weeker:
    #
    # Write code here.
    #

    def __init__(self, day):
        #
        # Write code here.
        #

    def __str__(self):
        #
        # Write code here.
        #

    def add_days(self, n):
        #
        # Write code here.
        #

    def subtract_days(self, n):
        #
        # Write code here.
        #


try:
    weekday = Weeker('Mon')
    print(weekday)
    weekday.add_days(15)
    print(weekday)
    weekday.subtract_days(23)
    print(weekday)
    weekday = Weeker('Monday')
except WeekDayError:
    print("Sorry, I can't serve your request.")

# %% [markdown]
# # Egzersiz 3
#
# ## Hedefler:
# - Öğrencinin sıfırdan sınıf oluşturma becerilerini geliştirmek
# - Örnek değişkenleri tanımlamayı ve kullanmayı öğrenmek
# - Metotları tanımlamayı ve kullanmayı öğrenmek
#
# ## Senaryo:
# Çok özel bir yeri ziyaret edelim - Kartezyen koordinat sistemine sahip bir düzlem (bu kavram hakkında daha fazla bilgi edinebilirsiniz: [Kartezyen koordinat sistemi](https://en.wikipedia.org/wiki/Cartesian_coordinate_system)).
#
# Düzlemde bulunan her nokta, geleneksel olarak x ve y olarak adlandırılan bir koordinat çifti ile tanımlanabilir. Bu koordinatları float sayılar olarak saklayan bir Python sınıfı yazabilmenizi bekliyoruz. Ayrıca, bu sınıfın nesnelerinin, düzlemdeki herhangi iki nokta arasındaki mesafeyi değerlendirebilmesini istiyoruz.
#
# Bu görev, hipotenüsün uzunluğunu değerlendiren hypot() fonksiyonunu (math modülü aracılığıyla erişilebilir) kullanırsanız oldukça kolaydır (daha fazla bilgi burada: [Hipotenüs](https://en.wikipedia.org/wiki/Hypotenuse) ve [Python Math Modülü](https://docs.python.org/3.7/library/math.html#trigonometric-functions)).
#
# Sınıfı şu şekilde hayal ediyoruz:
#
# - Sınıfın adı Point olacak;
# - Kurucusu iki argüman (x ve y) kabul eder ve her ikisi de varsayılan olarak sıfırdır;
# - Tüm özellikler özel olmalıdır;
# - Sınıf, getx() ve gety() adlı iki parametresiz metoda sahip olmalı, bu metotlar sırasıyla her iki koordinatı döndürür (koordinatlar özel olarak saklanır, bu nedenle nesnenin dışından doğrudan erişilemez);
# - Sınıf, distance_from_xy(x, y) adlı bir metod sağlamalı, bu metot nesnenin içinde saklanan nokta ile verilen bir nokta arasındaki mesafeyi hesaplayıp döndürür;
# - Sınıf, distance_from_point(point) adlı bir metod sağlamalı, bu metot mesafeyi (önceki metoda benzer şekilde) hesaplar, ancak diğer noktanın konumu başka bir Point sınıfı nesnesi olarak verilir;
#
# Editörde sağlanan şablonu tamamlayın, kodunuzu çalıştırın ve çıktınızın bizimkiyle aynı görünüp görünmediğini kontrol edin.
#
# ## Beklenen Çıktı:
# 1.4142135623730951
# 1.4142135623730951

# %%
import math


class Point:
    def __init__(self, x=0.0, y=0.0):
        #
        # Write code here
        #

    def getx(self):
        #
        # Write code here
        #

    def gety(self):
        #
        # Write code here
        #

    def distance_from_xy(self, x, y):
        #
        # Write code here
        #

    def distance_from_point(self, point):
        #
        # Write code here
        #


point1 = Point(0, 0)
point2 = Point(1, 1)
print(point1.distance_from_point(point2))
print(point2.distance_from_xy(2, 0))

# %% [markdown]
# # Egzersiz 4
#
# ## Hedefler:
# - Öğrencinin sıfırdan sınıf oluşturma becerilerini geliştirmek
# - Bileşimi kullanmayı öğrenmek
#
# ## Senaryo:
# Şimdi Point sınıfını (bkz. Lab 3.4.1.14) başka bir sınıfın içine yerleştireceğiz. Ayrıca, üç noktayı tek bir sınıfa koyarak bir üçgen tanımlayacağız. Bunu nasıl yapabiliriz?
#
# Yeni sınıf Triangle olarak adlandırılacak ve beklentilerimiz şunlardır:
#
# - Kurucu, hepsi Point sınıfının nesneleri olan üç argüman kabul eder.
# - Noktalar, nesnenin içinde özel bir liste olarak saklanır.
# - Sınıf, perimeter() adlı parametresiz bir metod sağlar ve bu metod, üç nokta tarafından tanımlanan üçgenin çevresini hesaplar. Çevre, tüm kenarların uzunluklarının toplamıdır (bunu tamlık adına belirtiyoruz, bunu zaten çok iyi bildiğinizden eminiz).
#
# Editörde sağlanan şablonu tamamlayın. Kodunuzu çalıştırın ve hesaplanan çevrenin bizimkiyle aynı olup olmadığını kontrol edin.
#
# Aşağıda, önceki laboratuvarda kullandığımız Point sınıfı kodunu bulabilirsiniz:
#
# ```python
# class Point:
#     def __init__(self, x=0.0, y=0.0):
#         self.__x = x
#         self.__y = y
# ```
#
# ## Beklenen Çıktı:
# 3.414213562373095

# %%
import math


class Point:
    #
    # The code copied from the previous lab.
    #


class Triangle:
    def __init__(self, vertice1, vertice2, vertice3):
        #
        # Write code here
        #

    def perimeter(self):
        #
        # Write code here
        #


triangle = Triangle(Point(0, 0), Point(1, 0), Point(0, 1))
print(triangle.perimeter())
